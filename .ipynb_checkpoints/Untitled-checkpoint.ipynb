# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Normal
import numpy as np
import matplotlib.pyplot as plt
import gym

# %%
eps=1e-10
DTYPE = torch.float32

# %%
class Net(nn.Module):
    def __init__(self, state_size, action_size, is_continuous=False):
        super().__init__()
        self.is_continuous = is_continuous
        
        pi_model = nn.Sequential(
            nn.Linear(state_size, 2),
            nn.ReLU(),
            nn.Linear(2, 2),
            nn.ReLU(),
            nn.Linear(2, 1),
            nn.ReLU(),
            nn.Linear(1, action_size)
        )
        
        value_model = nn.Sequential(
            nn.Linear(state_size, 50),
            nn.ReLU(),
            nn.Linear(50, 50),
            nn.ReLU(),
            nn.Linear(50, 50),
            nn.ReLU(),
            nn.Linear(50, 1)
        )
        
        self.pi = pi_model
        self.ve = value_model
        
    def forward(self, x):
        pass
    
    def getValue(self, x):
        x = torch.tensor(x, dtype=DTYPE)
        return self.ve(x)
    
    def getPi(self, x):
        x = torch.tensor(x, dtype=DTYPE)
        probs = self.pi(x)
        return nn.Softmax(dim=-1)(probs) if not self.is_continuous else probs 
    
    def setContinuous(self):
        self.is_continuous = True

# %%
class ReplayBuffer():
    def __init__(self, minl, maxl,alpha,sample_size=400):
        self.max_length = maxl
        self.length = 0
        self.buffer = []
        self.weights = []
        self.alpha = alpha
        self.min_length = minl
        self.sample_size = sample_size
        
    def add(self, ep):
        
        weight = np.exp(self.alpha*np.array(ep['rewards']).sum())+eps
#         if self.length>0 and weight < 0.75*np.min(self.weights) + 0.25 * np.mean(self.weights) and self.trainable(): return

        self.buffer.append(ep)
        self.length += 1

        self.weights.append(weight)
        
        if self.length > self.max_length:
            idx = np.random.randint(self.length)
            del self.buffer[idx]
            del self.weights[idx]
            self.length-=1
            
    def sample(self):
        wts = np.array(self.weights)
        
        sample_size = min(self.sample_size, self.length)
        sample = np.random.choice(self.buffer,size=(sample_size,), p=wts/wts.sum(), replace=False)
        out = sample if self.length>1 else [sample]
        return out
    
    def trainable(self):
        return self.length>self.min_length

# %%
class PCL(object):
    def __init__(self, env, replay_buffer, state_size, action_size, epoch=1000, off_policy_rate=20, pi_lr=7e-4, 
                 ve_lr=3.5e-4, entropy_tau=0.15, rollout_d=20, gamma=1):
        self.epoch = epoch
        self.state_size =  state_size
        self.action_size = action_size
        self.net = Net(self.state_size, self.action_size)
        self.net.is_continuous = False
        
        self.replay_buffer = replay_buffer
        self.env = env
        
        self.pi_optimiser = optim.Adam(self.net.pi.parameters(), lr=pi_lr)
        self.ve_optimiser = optim.Adam(self.net.ve.parameters(), lr=ve_lr)
        self.off_policy_rate = off_policy_rate
        self.tau = entropy_tau
        self.rollout_d = rollout_d
        self.gamma = gamma
    
    def selectProb(self, pi, a):
        a = np.eye(self.action_size, dtype=np.int32)[a]
        pi_selected = torch.sum(pi * torch.tensor(a, dtype=DTYPE), dim=1)
        return torch.log(pi_selected+eps)

        
    def optimise(self, episodes):
        net = self.net
        
        self.pi_optimiser.zero_grad()
        self.ve_optimiser.zero_grad()
        
#         print("before loop", episodes)
        for episode in episodes:
            rollout_d = min(self.rollout_d, len(episode['states']))
            ma = len(episode['states'])-rollout_d+1
            
            for i in range(ma):
                states = episode['states'][i:i+rollout_d]
                a = episode['actions'][i:i+rollout_d]  
                R = episode['rewards'][i:i+rollout_d]

                ve_init = net.getValue(states[0])
                ve_end = net.getValue(states[-1])

                pi_all_states = net.getPi(states).squeeze(0)
                log_pi_selected = self.selectProb(pi_all_states, a)

                discount = torch.tensor(self.gamma**np.arange(0,rollout_d))

                c = -ve_init + self.gamma**rollout_d*ve_end\
                + torch.sum(discount*(torch.tensor(R) - self.tau*log_pi_selected))

                loss = c**2
                loss.backward()
                
#                 print("----------------------------", loss)
#         print("after loop")
        
        self.ve_optimiser.step()
        self.pi_optimiser.step()
        
    def getStateEnc(self,x):
        return x
    def getStateDec(self,x):
        return x
    def getActionEnc(self,a):
        return a
    def getActionDec(self,a):
        return a
    
    def getAction(self, state):
        enc_state = self.getStateEnc(state)
        
        pi = self.net.getPi(enc_state).squeeze(0).detach().numpy()
        return self.getActionDec(np.random.choice(np.arange(self.action_size), p=pi))
    
    def rollout(self, max_ep_length = -1):
        states = []
        actions = []
        rewards = []
        env = self.env
        
        state = env.reset()
        is_terminated = False
        timestep = 0
        
        while not is_terminated and timestep!=max_ep_length:
            action = self.getAction(state)
            next_state, reward, is_terminated, _ = env.step(action)
            
            states.append(self.getStateEnc(state))
            actions.append(self.getActionEnc(action))
            rewards.append(reward)
            
            state = next_state
            timestep += 1

        
        rewards = np.array(rewards)
#         print(np.mean(rewards))
#         rewards = (rewards - np.mean(rewards))
        
#         print(len(states))
#         print("")
        return dict(
            states = states,
            actions = actions,
            rewards = list(rewards)
        )
    
    def train(self, max_ep_length=-1):
        tot_rewards = []
        for i in range(self.epoch):
            episode = self.rollout(max_ep_length)        
            self.optimise([episode])
            
            r = np.array(episode['rewards'])
            tot_rewards.append(r.sum())
            
#             if i>20: 
#                 print("I: {},    B:{}       R: {}                    ".format(i, self.replay_buffer.length, np.mean(tot_rewards[-20:])), end='\r')
#             else:
#                 print("I: {},    B:{}       R: {}                    ".format(i, self.replay_buffer.length, tot_rewards[-1]), end='\r')
                
            self.replay_buffer.add(episode)
            
            ########off policy
            if self.replay_buffer.trainable():
                for _ in range(self.off_policy_rate):
                    episodes = self.replay_buffer.sample()
                    self.optimise(episodes)
            
#             print(i)
#             for x in self.net.pi.parameters():
#                 print(x)

# %%
class ContinuousPCL(PCL):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.net.setContinuous()
        
    def selectProb(self, params, a):
        """
        params: [mean, var]
        """
        
        mean = params[:, 0]
        std = params[:, 1]
        a = torch.tensor(a, dtype=DTYPE)
        
        return -(a-mean)**2/(std**2+eps) - std  
    
    def getAction(self, state):
        enc_state = self.getStateEnc(state)
        params = self.net.getPi(enc_state).squeeze(0).detach()
        action = Normal(params[0], params[1]).sample().numpy()
        return np.array([action])
    
    def getActionEnc(self, action):
        return torch.tensor(action, dtype=DTYPE)

# %%
class CopyPCL(PCL):
    def __init__(self,*args, **kwargs):
        super().__init__(*args, **kwargs)
    
    def getStateEnc(self,x):
        return np.array([x])
    
    def getStateDec(self,x):
        return x[0]
    
    def getActionEnc(self,a):
        return a[0]*10 + a[1]*5 + a[2]
    
    def getActionDec(self,a):
        b = ((a//10)%5, 1-(a//10), (a%10)%5)
        return b

# %%
env = gym.make('Copy-v0')
buffer = ReplayBuffer(32, 10000, 1)
agent = CopyPCL(env, buffer, 1, 11, epoch=100000, off_policy_rate=2, pi_lr=0.005, ve_lr=0.0025)
# agent.getStateEnc = lambda x: np.eye(6)[int(x)]
# agent.getStateDec = lambda x: np.argmax(x)

# %%
agent.train()
# Out:
# before loop [{'states': [array([2]), array([4]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}]
# ---------------------------- tensor([3.2150], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0064], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}]
# ---------------------------- tensor([1.2767], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}]
# ---------------------------- tensor([0.8658], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}]
# ---------------------------- tensor([1.9284], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0087], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, -0.5]}]
# ---------------------------- tensor([0.2128], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0096], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, 1.0]}]
# ---------------------------- tensor([2.1109], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0080], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0162], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([3]), array([5]), array([3])], 'actions': [8, 10, 7], 'rewards': [1.0, 0.0, -0.5]}]
# ---------------------------- tensor([3.0017], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0122], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0167], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0087], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0170], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0112], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0092], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0079], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1])], 'actions': [9], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0077], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([0])], 'actions': [9], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0076], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([2]), array([5])], 'actions': [7, 5], 'rewards': [1.0, -0.5]}]
# ---------------------------- tensor([1.1410], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0132], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([2])], 'actions': [6], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0132], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0177], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([2])], 'actions': [8], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0177], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4]), array([5])], 'actions': [9, 5], 'rewards': [1.0, -0.5]}]
# ---------------------------- tensor([0.6692], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0092], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([2])], 'actions': [5], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0091], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4]), array([5])], 'actions': [9, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([2]), array([5])], 'actions': [7, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2]), array([4]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([0])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([3]), array([5]), array([3])], 'actions': [8, 10, 7], 'rewards': [1.0, 0.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, 1.0]}
#  {'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([2])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.7007], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.3696], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0130], grad_fn=<PowBackward0>)
# ---------------------------- tensor([3.0293], grad_fn=<PowBackward0>)
# ---------------------------- tensor([3.4730], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.6979], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0065], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.9400], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0388], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0090], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.7653], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0090], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0091], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0064], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0091], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0131], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0064], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.7204], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0175], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0175], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0064], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0175], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0131], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0131], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0175], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0091], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0175], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0091], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([3]), array([5]), array([3])], 'actions': [8, 10, 7], 'rewards': [1.0, 0.0, -0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, 1.0]}
#  {'states': [array([2]), array([5])], 'actions': [7, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2]), array([4]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([1])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0090], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.8275], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.9360], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0091], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.8073], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.2082], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.1751], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0113], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0129], grad_fn=<PowBackward0>)
# ---------------------------- tensor([3.0259], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0174], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0061], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0113], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.0894], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0128], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0128], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.3860], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0062], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0113], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0091], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0113], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0062], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0061], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0091], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0091], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0174], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0113], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0174], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0174], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.1434], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0091], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0129], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0174], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1]), array([5])], 'actions': [6, 9], 'rewards': [1.0, -0.5]}]
# ---------------------------- tensor([0.2890], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, 1.0]}
#  {'states': [array([4]), array([5])], 'actions': [9, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([1])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([2]), array([4]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 9], 'rewards': [1.0, -0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([2]), array([5])], 'actions': [7, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([3]), array([5]), array([3])], 'actions': [8, 10, 7], 'rewards': [1.0, 0.0, -0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [9], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0053], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.1981], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.5974], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.1761], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.1671], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.0922], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0055], grad_fn=<PowBackward0>)
# ---------------------------- tensor([3.0141], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0093], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.1123], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0588], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0093], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0014], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0172], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0124], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0092], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0094], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0172], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0172], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0094], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0054], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0171], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.9231], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0124], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0123], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0092], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0122], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0171], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0056], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, 1.0]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([2]), array([5])], 'actions': [7, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 9], 'rewards': [1.0, -0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([2])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([3]), array([5]), array([3])], 'actions': [8, 10, 7], 'rewards': [1.0, 0.0, -0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([2]), array([4]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([0])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}]
# ---------------------------- tensor([1.8109], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.1944], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0534], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0004], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.2221], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0121], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0321], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0238], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.9143], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([3.0041], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0052], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0112], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0172], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0051], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0093], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.2421], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0170], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0170], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0094], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0095], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0172], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0122], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0122], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0050], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0120], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0095], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0171], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0096], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0049], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0096], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}]
# ---------------------------- tensor([3.5881e-06], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([3]), array([5]), array([3])], 'actions': [8, 10, 7], 'rewards': [1.0, 0.0, -0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([2]), array([4]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 9], 'rewards': [1.0, -0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, 1.0]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([2]), array([5])], 'actions': [7, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([2])], 'actions': [8], 'rewards': [-0.5]}]
# ---------------------------- tensor([1.4054], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.8947], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0168], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0101], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.9787], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.1198], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0119], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.8137], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0239], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0239], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0100], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0045], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0100], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0117], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0097], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0170], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.2179], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0041], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0168], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.3852], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0115], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0004], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0101], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0044], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0098], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0119], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0043], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0170], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0315], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0169], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([2]), array([4]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([3]), array([5]), array([3])], 'actions': [8, 10, 7], 'rewards': [1.0, 0.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, 1.0]}
#  {'states': [array([1])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 9], 'rewards': [1.0, -0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([2]), array([5])], 'actions': [7, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([2])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([2])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [9], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0116], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.3953], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.9640], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0170], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0167], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.8842], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.9308], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0040], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.1432], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0170], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0100], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0103], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.2372], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0116], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0012], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0363], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0039], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0167], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0116], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0363], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0099], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.4156], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0116], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0449], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0169], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0118], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0116], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0102], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0113], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0102], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0038], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0103], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0117], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0118], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0042], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0166], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, 1.0]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([2]), array([5])], 'actions': [7, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([1])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([3]), array([5]), array([3])], 'actions': [8, 10, 7], 'rewards': [1.0, 0.0, -0.5]}
#  {'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([2])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([2]), array([4]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([2])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 9], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [9], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0124], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0167], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0165], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.6546], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0017], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0121], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0169], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0031], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.1764], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0034], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0110], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.3334], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0108], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.8626], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0104], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0124], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0167], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0117], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0122], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.9323], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0105], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0121], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.3538], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0853], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0165], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0117], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0123], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0110], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0165], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0122], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0169], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0032], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0108], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0036], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 9], 'rewards': [1.0, -0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([2]), array([5])], 'actions': [7, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, 1.0]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([3]), array([5]), array([3])], 'actions': [8, 10, 7], 'rewards': [1.0, 0.0, -0.5]}
#  {'states': [array([2])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([2]), array([4]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}]
# ---------------------------- tensor([0.0168], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0011], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0444], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0125], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0164], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.1302], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0025], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0113], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0164], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.4011], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0011], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0113], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0031], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0033], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.8516], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0126], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.2810], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0028], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0164], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0117], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0124], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0167], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0125], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0106], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.3012], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0111], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0029], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0168], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.9155], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0164], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0117], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0108], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0124], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}]
# ---------------------------- tensor([1.2305], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, 1.0]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([2])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([3]), array([5]), array([3])], 'actions': [8, 10, 7], 'rewards': [1.0, 0.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([2]), array([5])], 'actions': [7, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([2])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([2]), array([4]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 9], 'rewards': [1.0, -0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}]
# ---------------------------- tensor([1.1612], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.7612], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0117], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0114], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.1416], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0165], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.1444], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0110], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.8295], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0344], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0371], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0131], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0118], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0344], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0133], grad_fn=<PowBackward0>)
# ...
# ---------------------------- tensor([0.0065], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0018], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0177], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0283], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0283], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0065], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0399], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.1517], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0017], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0283], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.2564], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0392], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0066], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0397], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0017], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0390], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0390], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0392], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0282], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0283], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0175], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0281], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.3738], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0177], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0392], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0177], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0176], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0066], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0066], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0065], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0175], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0065], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([3]), array([5])], 'actions': [8, 9], 'rewards': [1.0, 1.0]}
#  {'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([2])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 9], 'rewards': [1.0, -0.5]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([3]), array([5]), array([5])], 'actions': [8, 6, 8], 'rewards': [1.0, 1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, 1.0]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([2]), array([5])], 'actions': [7, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([2]), array([4]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 9], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([3]), array([5]), array([3])], 'actions': [8, 10, 7], 'rewards': [1.0, 0.0, -0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([2])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([2]), array([3]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}]
# ---------------------------- tensor([1.3459], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.1775], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.5500], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0181], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0399], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.3393], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0093], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0285], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0285], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0396], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0286], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.9695], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.5248], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0183], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0064], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0399], grad_fn=<PowBackward0>)
# ---------------------------- tensor([1.0447], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0066], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0407], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0064], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0183], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.1386], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0181], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.5500], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.4190], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0286], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0018], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0396], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.2409], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0064], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0093], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0065], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0018], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0407], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.1775], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0286], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0404], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0064], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.2063], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0183], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0018], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0019], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.6015], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.1405], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0399], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0284], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0183], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0283], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0404], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0019], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0181], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0064], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0286], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0018], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0066], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0066], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([1]), array([5])], 'actions': [6, 9], 'rewards': [1.0, -0.5]}]
# ---------------------------- tensor([0.2514], grad_fn=<PowBackward0>)
# after loop
# before loop [{'states': [array([2]), array([3]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([2]), array([4]), array([2])], 'actions': [10, 7, 5], 'rewards': [0.0, 1.0, -0.5]}
#  {'states': [array([2]), array([5])], 'actions': [7, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([3]), array([5]), array([5])], 'actions': [8, 6, 8], 'rewards': [1.0, 1.0, -0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([3]), array([5])], 'actions': [8, 9], 'rewards': [1.0, 1.0]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 9], 'rewards': [1.0, -0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 8], 'rewards': [1.0, -0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0]), array([5])], 'actions': [5, 6], 'rewards': [1.0, -0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([3]), array([5]), array([3])], 'actions': [8, 10, 7], 'rewards': [1.0, 0.0, -0.5]}
#  {'states': [array([2])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 9], 'rewards': [1.0, -0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, 1.0]}
#  {'states': [array([2])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([1]), array([5])], 'actions': [6, 5], 'rewards': [1.0, -0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([1])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 9], 'rewards': [1.0, -0.5]}
#  {'states': [array([3])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4]), array([5])], 'actions': [9, 7], 'rewards': [1.0, -0.5]}
#  {'states': [array([0])], 'actions': [7], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([3])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [6], 'rewards': [-0.5]}
#  {'states': [array([2])], 'actions': [5], 'rewards': [-0.5]}
#  {'states': [array([0])], 'actions': [9], 'rewards': [-0.5]}
#  {'states': [array([4])], 'actions': [8], 'rewards': [-0.5]}]
# ---------------------------- tensor([2.1196], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0191], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0062], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.0289], grad_fn=<PowBackward0>)
# ---------------------------- tensor([0.1097], grad_fn=<PowBackward0>)
# ---------------------------- tensor([2.1173], grad_fn=<PowBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-280-3d92c9b1ff97> in <module>
# ----> 1 agent.train()
#
# <ipython-input-276-fd11cdcd2500> in train(self, max_ep_length)
#     129                 for _ in range(self.off_policy_rate):
#     130                     episodes = self.replay_buffer.sample()
# --> 131                     self.optimise(episodes)
#     132
#     133 #             print(i)
#
# <ipython-input-276-fd11cdcd2500> in optimise(self, episodes)
#      52
#      53                 loss = c**2
# ---> 54                 loss.backward()
#      55
#      56                 print("----------------------------", loss)
#
# /envs/rl/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     148                 products. Defaults to ``False``.
#     149         """
# --> 150         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     151
#     152     def register_hook(self, hook):
#
# /envs/rl/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
agent.getAction(0)
# Out:
# (0, 1, 3)
